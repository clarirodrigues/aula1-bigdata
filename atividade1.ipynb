# %%
import pandas as pd
import numpy as np

# %%
dictViagem= {'Hong Kong': 29800.000,
               'Bangkok': 23600.000,
               'Londres':20700.000,
               'Macau':18900.000,
               'Cingapura':18500.000,
               'Paris':16800.000,
               'Dubai': 16600.000,
               'Nova York':13500.000,
               'Kuala Lumpur': 13400.000,
               'Shenzhen':  12400.000

}

# %%
serie1=pd.Series(dictViagem)
serie1
# Out:
# Hong Kong       29800.0
# Bangkok         23600.0
# Londres         20700.0
# Macau           18900.0
# Cingapura       18500.0
# Paris           16800.0
# Dubai           16600.0
# Nova York       13500.0
# Kuala Lumpur    13400.0
# Shenzhen        12400.0
# dtype: float64

# %%
destinos=['Hong Kong','Bangkok', 'Londres','Macau','Cingapura','Paris','Dubai','Nova York','Kuala Lumpur', 'Shenzhen']

# %%
visitantes=[29800.0,23600.0,20700.0, 18900.0, 18500.0, 16800.0, 16600.0, 13500.0, 13400.0,12400.0]

# %%
serie2=pd.Series(visitantes, index= dictViagem)
serie2
# Out:
# Hong Kong       29800.0
# Bangkok         23600.0
# Londres         20700.0
# Macau           18900.0
# Cingapura       18500.0
# Paris           16800.0
# Dubai           16600.0
# Nova York       13500.0
# Kuala Lumpur    13400.0
# Shenzhen        12400.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
serie2.plot()
# Out:
# <Axes: >
